# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv('../data/united_customers_synthetic.csv')

# %%
df['mileage_plus_status'].unique()
# Out:
# array(['Silver', 'Platinum', '1K', 'Gold', 'Basic'], dtype=object)

# %%
df['priority_pass'] = [random.choices([0, 1], weights=[6, 4], k=1)[0] for _ in range(len(df))]
df['united_club'] = np.where(df['mileage_plus_status'] != 'Basic', 1, 0)

# %%
df.head()
# Out:
#   customer_id   first_name last_name                       email  \
# 0   CUST00000          Amy   Roberts       amy.roberts@gmail.com
# 1   CUST00001  Christopher      Bass  christopher.bass@gmail.com
# 2   CUST00002    Stephanie      Bell    stephanie.bell@yahoo.com
# 3   CUST00003     Courtney   Johnson  courtney.johnson@yahoo.com
# 4   CUST00004       Thomas   Randall    thomas.randall@yahoo.com
#
#             phone_number date_of_birth             gender  \
# 0    +1-659-342-3209x471    1946-09-09                  F
# 1             9032173008    1992-05-22                  M
# 2  +1-599-246-6109x35233    1995-06-15                  F
# 3           428-512-4000    1962-06-19  Prefer not to say
# 4           717-604-5229    1985-07-30                  M
#
#                         address                  city state  ...  \
# 0            01868 Boyd Freeway         Lake Brittany    OR  ...
# 1            1314 Graham Circle         Williamsville    MO  ...
# ...

# %%
df.to_csv('../data/customers.csv', index=False)
